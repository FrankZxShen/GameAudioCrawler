# %%
# 测试网址是否可用
import time
import requests
print("看响应参数是不是200判断url是否能访问")
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
    'Referer': 'https://fgo.wiki/w/',
    'csrf': 'RUJ53PGJ4ZD',
    'Cookie': 'Hm_lvt_cdb524f42f0ce19b169a8071123a4797=1577029678,1577034191,1577034210,1577076651; Hm_lpvt_cdb524f42f0ce19b169a8071123a4797=1577080777; kw_token=RUJ53PGJ4ZD'
}
response = requests.get(
    "https://fgo.wiki/images/3/3a/SV380_0_%E5%BC%80%E5%A7%8B1.mp3", headers=headers)
print(response)
# Out:
# 看响应参数是不是200判断url是否能访问
# <Response [200]>

# %%
# 测试音频是否存在
from bs4 import BeautifulSoup  
import re
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
    'Referer': 'https://fgo.wiki/w/',
    'csrf': 'RUJ53PGJ4ZD',
    'Cookie': 'Hm_lvt_cdb524f42f0ce19b169a8071123a4797=1577029678,1577034191,1577034210,1577076651; Hm_lpvt_cdb524f42f0ce19b169a8071123a4797=1577080777; kw_token=RUJ53PGJ4ZD'
}
url = 'https://m.fgo.wiki/w/%E9%98%BF%E5%B0%94%E6%89%98%E8%8E%89%E9%9B%85%C2%B7%E5%8D%A1%E6%96%AF%E7%89%B9' 
res = requests.get(url, headers=headers).text 
content = BeautifulSoup(res, "html.parser") 
data = content.find_all('audio', attrs={'onended': 'mini_audio_player_end(this)'}) 
# <audio onended="mini_audio_player_end(this)" preload="none">
# 		<source src="//fgo.wiki/images/d/d1/SV284_2_%E5%BC%80%E5%A7%8B1.mp3">
# 		请升级<br>浏览器。
# 	</audio>
# print(data)
rex = re.compile('<source src="(.*?)"/>') 
audio_list = [] 
for d in data: 
    alist = re.findall(rex, str(d))
    audio_list.append('https:'+alist[0]) 
print(audio_list)
# Out:
# ['https://fgo.wiki/images/a/ac/SV284_0_%E5%BC%80%E5%A7%8B1.mp3', 'https://fgo.wiki/images/c/c4/SV284_0_%E5%BC%80%E5%A7%8B2.mp3', 'https://fgo.wiki/images/e/e1/SV284_0_%E5%BC%80%E5%A7%8B3.mp3', 'https://fgo.wiki/images/2/21/SV284_0_%E6%8A%80%E8%83%BD1.mp3', 'https://fgo.wiki/images/1/11/SV284_0_%E6%8A%80%E8%83%BD2.mp3', 'https://fgo.wiki/images/a/aa/SV284_0_%E6%8A%80%E8%83%BD3.mp3', 'https://fgo.wiki/images/a/a7/SV284_0_%E6%8A%80%E8%83%BD4.mp3', 'https://fgo.wiki/images/9/9d/SV284_0_%E6%8C%87%E4%BB%A4%E5%8D%A11.mp3', 'https://fgo.wiki/images/6/6b/SV284_0_%E6%8C%87%E4%BB%A4%E5%8D%A12.mp3', 'https://fgo.wiki/images/9/9f/SV284_0_%E6%8C%87%E4%BB%A4%E5%8D%A13.mp3', 'https://fgo.wiki/images/6/69/SV284_0_%E5%AE%9D%E5%85%B7%E5%8D%A11.mp3', 'https://fgo.wiki/images/5/56/SV284_0_%E5%AE%9D%E5%85%B7%E5%8D%A12.mp3', 'https://fgo.wiki/images/3/3d/SV284_0_%E5%AE%9D%E5%85%B7%E5%8D%A13.mp3', 'https://fgo.wiki/images/1/1e/SV284_0_%E6%94%BB%E5%87%BB1.mp3', 'https://fgo.wiki/images/9/97/SV284_0_%E6%94%BB
# ...

# %%
#!!!!!!!!!!!!!!!从这里开始执行
# 测试角色是否存在
# 生成角色名
# 6.4
import re
import requests
import re
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.by import By

# headers = {
#     'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
#     'Referer': 'https://fgo.wiki/w/%E8%8B%B1%E7%81%B5%E5%9B%BE%E9%89%B4',
#     'csrf': 'RUJ53PGJ4ZD',
#     'Cookie': 'Hm_lvt_cdb524f42f0ce19b169a8071123a4797=1577029678,1577034191,1577034210,1577076651; Hm_lpvt_cdb524f42f0ce19b169a8071123a4797=1577080777; kw_token=RUJ53PGJ4ZD'
# }
url = 'https://fgo.wiki/w/%E8%8B%B1%E7%81%B5%E5%9B%BE%E9%89%B4' 
# res = requests.get(url,headers=headers).text 
browser = webdriver.Chrome()
browser.minimize_window()
browser.get(url)
wait = WebDriverWait(browser,10) #等待变量
language_dropdown = browser.find_element(By.XPATH, "//select[@id='per-page']")
select_element = language_dropdown.find_element(By.XPATH, "//option[text()='500']")
select_element.click()
html = browser.page_source
c_audio_list = [] 
# print(html)
rex = re.compile('<a href="(.*?)">(.*?)</a>') 
alist = re.findall(rex, str(html))  
c_audio_list.append(alist[7:1158]) 
# for i in c_audio_list:
#     print(i)
c_audio = []
for i in c_audio_list[0]:
    if "<" in i[1]:
        continue
    c_audio.append(i[1])
print(c_audio)
browser.quit()
# Out:
# ['美杜莎', '杜尔伽', '难敌', '怖军', '果心居士', '瑟坦特', '洛库斯塔', '所多玛之兽／德拉科', '幼体／提亚马特', '高杉晋作', '女教皇若安', '库库尔坎', '特拉洛克', '特斯卡特利波卡', '尼托克丽丝〔Alter〕', '格里戈里・拉斯普京', '布里托玛特', '九纹龙伊丽莎', '黄飞虎', '呼延灼', '壹与', '山南敬助', '千利休', '奥特琳德', '希露德', '斯露德', '武则天', '斯卡哈・斯卡蒂', '宇津见绘里濑', '伊吹童子', '加雷斯', '阿瓦隆女士', '徐福', 'Archetype: Earth', '源为朝', '曲亭马琴', '张角', '堂・吉诃德', '詹姆斯・莫里亚蒂', '克里姆希尔德', '罗兰', '查理曼', '君士坦丁十一世', '玛丽・安宁', '大黑天', '超级班扬', '太岁星君', '征氏姐妹', '马纳南・麦克・利尔〔巴泽特〕', '赫费斯提翁', '暗之高扬斯卡娅', 'BeastⅣ', '多布雷尼亚・尼基季奇', '太公望', '玛尔达〔圣诞〕', '坂本龙马', '谜之兰丸X', '出云阿国', '伊丽莎白・巴托里〔灰姑娘〕', '芝诺比阿', '雅克・德・莫莱', '清少纳言', '凯妮斯', '迦摩', '莱昂纳多・达・芬奇', '夏洛特・科黛', '阿纳斯塔西娅＆维', '冲田总司〔Alter〕', '奥伯龙', '哈贝特洛特', '光之高扬斯卡娅', '珀西瓦尔', '妖精骑士兰斯洛特', '妖精骑士崔斯坦', '妖精骑士高文', '摩根', '谜之偶像X〔Alter〕', '克莱恩小姐', '伽拉忒亚', '阿摩耳〔卡莲〕', '鬼一法眼', '平景清', '千子村正', '迦尔纳〔圣诞〕', '弗栗多', '伊吹童子', '渡边纲', '芦屋道满', '尼莫', '梵高', '织田信胜', '斋藤一', '卑弥呼', '紫式部', '巴御前', '阿比盖尔・威廉姆斯〔夏〕', '虞美人', '布伦希尔德', '伊莉雅丝菲尔・冯・爱因兹贝伦', '杀生院祈荒', '阿尔托莉雅・卡斯特', '宇津见绘里濑', '鬼女红叶', '旅行者', '罗穆路斯・奎里努斯', '凯妮斯', '狄俄斯库里', '奥德修斯', '清少纳言
# ...

# %%
import os 
os.chdir('../')
os.getcwd()
# Out:
# 'd:\\Frank\\games\\makemyonwn\\fgo角色语音收录'

# %%
# 爬取角色音频
import os
import time
from bs4 import BeautifulSoup
import requests
from tqdm import *

def download_audio(audio_l,c_name): 
    if os.path.exists(c_name): 
        print(c_name," 已存在")
        # os.mkdir()
        # return
    else:
        os.mkdir(c_name) 
    
    for i in tqdm(audio_l): 
        audio = requests.get(i) 
        audio_name = i.split('/')[6] 
        with open(c_name + '\\' + audio_name, 'wb') as f: 
            f.write(audio.content)

def get_mp3_names(res):
    res = requests.get(url).text 
    content = BeautifulSoup(res, "html.parser") 
    data = content.find_all('audio', attrs={'onended': 'mini_audio_player_end(this)'}) 
    # <audio onended="mini_audio_player_end(this)" preload="none">
    # 		<source src="//fgo.wiki/images/d/d1/SV284_2_%E5%BC%80%E5%A7%8B1.mp3">
    # 		请升级<br>浏览器。
    # 	</audio>
    # print(data)
    rex = re.compile('<source src="(.*?)"/>') 
    audio_list = [] 
    for d in data: 
        alist = re.findall(rex, str(d))
        audio_list.append('https:'+alist[0]) 
    print(audio_list)
    return audio_list

print("开始爬取...")
print("#####################################################")
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
    'Referer': 'https://fgo.wiki/w/',
    'csrf': 'RUJ53PGJ4ZD',
    'Cookie': 'Hm_lvt_cdb524f42f0ce19b169a8071123a4797=1577029678,1577034191,1577034210,1577076651; Hm_lpvt_cdb524f42f0ce19b169a8071123a4797=1577080777; kw_token=RUJ53PGJ4ZD'
}
############################################################################################
# 开始执行爬取
os.chdir('./audio/')
more_name = []
for c_name in c_audio:
    if c_name in more_name:
        c_name = c_name+'_'+str(len(c_audio)-len(more_name)+1)
    more_name.append(c_name)
    url = 'https://fgo.wiki/w/' + c_name
#############################################################################################
    print("角色名：",c_name)
    try:
        # os.getcwd()
        res = requests.get(url, headers=headers).text 
        audio_list = get_mp3_names(res)
        download_audio(audio_list, c_name)
    except Exception as e:
        print("爬取 "+c_name + " 出现错误：",e)
    time.sleep(2)

print("#####################################################")
print("爬取结束...")
# Out:
# 开始爬取...
# #####################################################
# 角色名： 美杜莎
# ...

# %%
import os
os.chdir('./fgo角色语音收录/')
os.getcwd()
# Out:
# 'd:\\Frank\\games\\makemyonwn\\fgo角色语音收录'

# %%
# os.chdir('../')
# os.getcwd()
# rename
for c_name in tqdm(c_audio_list):
    path = './audio529/'+ c_name
    i = 1
    for filename in os.listdir(path):
        if filename.endswith('.mp3'):
            os.rename(os.path.join(path, filename), os.path.join(path, str(i) + '.wav'))
            i += 1

# %%
# 修复脚本
# 爬取角色音频
import os
import re
import time
from bs4 import BeautifulSoup
import requests
from tqdm import *
def download_audio(audio_l,c_name): 
    # if os.path.exists(c_name): 
    #     print(c_name," 已存在")
    #     return
    # else:
    #     os.mkdir(c_name) 
    
    for i in tqdm(audio_l): 
        audio = requests.get(i) 
        audio_name = i.split('/')[6] 
        with open(c_name + '\\' + audio_name, 'wb') as f: 
            f.write(audio.content)

def get_mp3_names(res):
    res = requests.get(url).text 
    content = BeautifulSoup(res, "html.parser") 
    data = content.find_all('audio', attrs={'onended': 'mini_audio_player_end(this)'}) 
    # <audio onended="mini_audio_player_end(this)" preload="none">
    # 		<source src="//fgo.wiki/images/d/d1/SV284_2_%E5%BC%80%E5%A7%8B1.mp3">
    # 		请升级<br>浏览器。
    # 	</audio>
    # print(data)
    rex = re.compile('<source src="(.*?)"/>') 
    audio_list = [] 
    for d in data: 
        alist = re.findall(rex, str(d))
        audio_list.append('https:'+alist[0]) 
    print(audio_list)
    return audio_list

print("开始爬取...")
print("#####################################################")
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/79.0.3945.88 Safari/537.36',
    'Referer': 'https://fgo.wiki/w/',
    'csrf': 'RUJ53PGJ4ZD',
    'Cookie': 'Hm_lvt_cdb524f42f0ce19b169a8071123a4797=1577029678,1577034191,1577034210,1577076651; Hm_lpvt_cdb524f42f0ce19b169a8071123a4797=1577080777; kw_token=RUJ53PGJ4ZD'
}
############################################################################################
# 开始执行爬取
os.chdir('./audio/')
c_audio_11 = ['冲田·J·总司','夏洛特·科黛','多布雷尼亚·尼基季奇','威廉·退尔','巴沙洛缪·罗伯茨','拉克什米·芭伊','格里戈里·拉斯普京','玛丽·安宁', \
              '罗穆路斯·奎里努斯','美游·艾德费尔特','谜之Alterego·Λ','阿尔托莉雅·卡斯特','阿比盖尔·威廉姆斯〔夏〕','马纳南·麦克·利尔〔巴泽特〕','魁札尔·科亚特尔〔桑巴／圣诞〕']
for c_name in c_audio_11:
    url = 'https://fgo.wiki/w/' + c_name
#############################################################################################
    print("角色名：",c_name)
    try:
        # os.getcwd()
        res = requests.get(url, headers=headers).text 
        audio_list = get_mp3_names(res)
        download_audio(audio_list, c_name)
    except Exception as e:
        print("爬取 "+c_name + " 出现错误：",e)
    time.sleep(2)

print("#####################################################")
print("爬取结束...")
# Out:
# 开始爬取...
# #####################################################
# 角色名： 冲田·J·总司
# ...

# %%
os.chdir('D:\Frank\games\makemyonwn\pcr角色语音收录')
os.getcwd()
for c_name in tqdm(c_audio_list2):
    path = './audio/'+ c_name
    i = 1
    for filename in os.listdir(path):
        if filename.endswith('.mp3'):
            os.rename(os.path.join(path, filename), os.path.join(path, str(i) + '.wav'))
            i += 1
